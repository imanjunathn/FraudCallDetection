# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
mainPath = '/content/gdrive/My Drive/AIML/HackerEarth/'

# %%
def loadFile(fileNamePath):
  data = pd.read_csv(mainPath+fileNamePath)
  print(data.shape)
  return data

# %%
fileNamePath = 'Dataset/Train.csv'
train_data_df = loadFile(fileNamePath=fileNamePath)
# Out:
# (23856, 18)

# %%
train_data_df.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  ...  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   CR_102659  04-JUL-04    0   36  ...    92    29    36                 0
# 1   CR_189752  18-JUL-17    1   37  ...   103   142    34                 1
# 2   CR_184637  15-MAR-17    0    3  ...   110    93    34                 1
# 3   CR_139071  13-FEB-09    0   33  ...    72    29    34                 1
# 4   CR_109335  13-APR-05    0   33  ...   112    29    43                 1
#
# [5 rows x 18 columns]

# %%
train_data_df.tail()
# Out:
#       INCIDENT_ID       DATE  X_1  X_2  ...  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 23851    CR_88991  11-JAN-02    1   47  ...    98    29    34                 1
# 23852    CR_46369  05-FEB-97    0   33  ...   112    29    43                 1
# 23853   CR_157556  03-APR-12    0   25  ...    10    29    18                 1
# 23854   CR_103180  25-JAN-04    0   39  ...   112   103    43                 1
# 23855    CR_22575  08-NOV-94    7   36  ...    92    29    34                 1
#
# [5 rows x 18 columns]

# %%
train_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INCIDENT_ID       23856 non-null  object
#  1   DATE              23856 non-null  object
#  2   X_1               23856 non-null  int64
#  3   X_2               23856 non-null  int64
#  4   X_3               23856 non-null  int64
#  5   X_4               23856 non-null  int64
#  6   X_5               23856 non-null  int64
#  7   X_6               23856 non-null  int64
#  8   X_7               23856 non-null  int64
#  9   X_8               23856 non-null  int64
#  10  X_9               23856 non-null  int64
#  11  X_10              23856 non-null  int64
#  12  X_11              23856 non-null  int64
#  13  X_12              23674 non-null  float64
#  14  X_13              23856 non-null  int64
#  15  X_14              23856 non-null  int64
# ...

# %%
testFileNamePath = 'Dataset/Test.csv'
test_data_df = loadFile(testFileNamePath)
# Out:
# (15903, 17)

# %%
test_data_df.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  ...  X_11  X_12  X_13  X_14  X_15
# 0   CR_195453  01-FEB-18    0   30   35  ...   174   NaN    72   119    23
# 1   CR_103520  05-MAR-04    0   44   44  ...   316   0.0    12    29    34
# 2   CR_196089  27-JAN-18    0   34   33  ...   316   1.0    72     0    34
# 3   CR_112195  18-AUG-06    7    3    2  ...   174   1.0   112    87    34
# 4   CR_149832  31-OCT-11    0    7    8  ...   174   0.0   112    93    43
#
# [5 rows x 17 columns]

# %%
test_data_df.tail()
# Out:
#       INCIDENT_ID       DATE  X_1  X_2  X_3  ...  X_11  X_12  X_13  X_14  X_15
# 15898    CR_44468  28-NOV-97    1   22   22  ...   174   0.0    72    29    43
# 15899   CR_158460  09-JUN-12    0   35   30  ...     0   2.0    72    93    34
# 15900   CR_115946  22-APR-06    0   26   27  ...     0   1.0    72    62    34
# 15901   CR_137663  03-APR-09    0   21   23  ...   249   2.0    92    62    34
# 15902    CR_33545  24-APR-96    0    4    4  ...   249   1.0    72    29    34
#
# [5 rows x 17 columns]

# %%
test_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15903 entries, 0 to 15902
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   INCIDENT_ID  15903 non-null  object
#  1   DATE         15903 non-null  object
#  2   X_1          15903 non-null  int64
#  3   X_2          15903 non-null  int64
#  4   X_3          15903 non-null  int64
#  5   X_4          15903 non-null  int64
#  6   X_5          15903 non-null  int64
#  7   X_6          15903 non-null  int64
#  8   X_7          15903 non-null  int64
#  9   X_8          15903 non-null  int64
#  10  X_9          15903 non-null  int64
#  11  X_10         15903 non-null  int64
#  12  X_11         15903 non-null  int64
#  13  X_12         15776 non-null  float64
#  14  X_13         15903 non-null  int64
#  15  X_14         15903 non-null  int64
#  16  X_15         15903 non-null  int64
# dtypes: float64(1), int64(14), object(2)
# memory usage: 2.1+ MB

# %%
# concated_df = pd.concat([train_data_df,test_data_df],axis=0)
concated_df = train_data_df.copy(True)
print(concated_df.shape)
concated_df.head()
# Out:
# (23856, 18)
#   INCIDENT_ID       DATE  X_1  X_2  ...  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   CR_102659  04-JUL-04    0   36  ...    92    29    36                 0
# 1   CR_189752  18-JUL-17    1   37  ...   103   142    34                 1
# 2   CR_184637  15-MAR-17    0    3  ...   110    93    34                 1
# 3   CR_139071  13-FEB-09    0   33  ...    72    29    34                 1
# 4   CR_109335  13-APR-05    0   33  ...   112    29    43                 1
#
# [5 rows x 18 columns]

# %%
concated_df.describe().T
# Out:
#                     count        mean        std  ...    50%    75%    max
# X_1               23856.0    0.483778   1.439738  ...    0.0    0.0    7.0
# X_2               23856.0   24.791206  15.240231  ...   24.0   36.0   52.0
# X_3               23856.0   24.637450  15.135093  ...   24.0   35.0   52.0
# X_4               23856.0    4.276744   2.944672  ...    4.0    6.0   10.0
# X_5               23856.0    2.455609   1.963095  ...    3.0    5.0    5.0
# X_6               23856.0    6.154175   4.471756  ...    5.0    8.0   19.0
# X_7               23856.0    4.876509   3.881931  ...    4.0    7.0   18.0
# X_8               23856.0    0.972460   1.453144  ...    1.0    1.0   99.0
# X_9               23856.0    4.924128   1.362625  ...    5.0    6.0    6.0
# X_10              23856.0    1.244802   1.119301  ...    1.0    1.0   90.0
# X_11              23856.0  206.954519  93.033348  ...  249.0  249.0  332.0
# ...

# %%
concated_df.isna().sum()
# Out:
# INCIDENT_ID           0
# DATE                  0
# X_1                   0
# X_2                   0
# X_3                   0
# X_4                   0
# X_5                   0
# X_6                   0
# X_7                   0
# X_8                   0
# X_9                   0
# X_10                  0
# X_11                  0
# X_12                182
# X_13                  0
# X_14                  0
# X_15                  0
# MULTIPLE_OFFENSE      0
# dtype: int64

# %%
concated_df.drop(columns=['INCIDENT_ID','DATE'],inplace=True)

# %%
sns.distplot(concated_df.X_1,kde=True)
print(concated_df.X_1.unique())
# I assume, this column contains categorical ordinal values.
# Isnstead of checking distribution of density, I check count distribution.
# Out:
# [0 1 5 7 3 4 2 6]

# %%
sns.countplot(concated_df.X_1,hue=concated_df.MULTIPLE_OFFENSE)
for val in range(concated_df.X_1.max()+1):
  print(f'distribution of value {val}: {np.round(len(concated_df.X_1[concated_df.X_1 == val])/len(concated_df.X_1),2)}%')
  # 95% percent of the data is dstributed between value '0' and '1'
print(concated_df.groupby(['MULTIPLE_OFFENSE']).X_1.value_counts(normalize=False).unstack())
concated_df.groupby(['MULTIPLE_OFFENSE']).X_1.value_counts(normalize=False).unstack().plot(stacked=False,kind='bar')
# Out:
# distribution of value 0: 0.8%
# distribution of value 1: 0.15%
# distribution of value 2: 0.0%
# distribution of value 3: 0.01%
# distribution of value 4: 0.0%
# distribution of value 5: 0.01%
# distribution of value 6: 0.0%
# distribution of value 7: 0.04%
# X_1                     0       1     2      3     4      5    6      7
# MULTIPLE_OFFENSE
# 0                   842.0   189.0   NaN    NaN   NaN   15.0  1.0   21.0
# 1                 18194.0  3308.0  10.0  136.0  26.0  255.0  4.0  855.0

# %%
# Let's check distribution of X_2
sns.distplot(concated_df.X_2,kde=True,bins=30)
print(f'Skewness of X_2:',concated_df.X_2.skew())
# Skewness is almost '0'.
# And the distribution is approximately symmetric.
# Out:
# Skewness of X_2: -0.09475210719710903

# %%
# Let's check distribution of X_3
sns.distplot(concated_df.X_3,kde=True)
print(f'Skewness of X_3:',concated_df.X_3.skew())
# Skewness is almost '0'.
# And It's almost normally distributed
# Out:
# Skewness of X_3: -0.08212039853941026

# %%
# Let's check distribution of X_4
sns.distplot(concated_df.X_4,kde=True)
print(f'Unique values: {concated_df.X_4.unique()}')
concated_df.X_4.describe().T

# I assume, this column contains categorical ordinal values.
# Isnstead of checking distribution of density, I check count distribution.
# Out:
# Unique values: [ 2  0  3 10  7  6  9  4  1  5]
# count    23856.000000
# mean         4.276744
# std          2.944672
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%          6.000000
# max         10.000000
# Name: X_4, dtype: float64

# %%
sns.countplot(concated_df.X_4,hue=concated_df.MULTIPLE_OFFENSE)
for val in range(concated_df.X_4.max()+1):
  print(f'distribution of value {val}: {np.round(len(concated_df.loc[concated_df.X_4 == val])/len(concated_df.X_4),2)}%')
print('---------')
print(f'distribution of value according MULTIPLE Offence 1: {np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 1])/len(concated_df.X_4),2)}%')
print(f'distribution of value according MULTIPLE Offence 0: {np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 0])/len(concated_df.X_4),2)}%')
# As we can see, 96% of the data distributted as Multiple_Offence true.
# And 4% of the data distributted as Multiple_Offence false
# Out:
# distribution of value 0: 0.14%
# distribution of value 1: 0.04%
# distribution of value 2: 0.2%
# distribution of value 3: 0.08%
# distribution of value 4: 0.08%
# distribution of value 5: 0.0%
# distribution of value 6: 0.23%
# distribution of value 7: 0.12%
# distribution of value 8: 0.0%
# distribution of value 9: 0.06%
# distribution of value 10: 0.05%
# ---------
# distribution of value according MULTIPLE Offence 1: 0.96%
# distribution of value according MULTIPLE Offence 0: 0.04%

# %%
# Let's check distribution of X_5
sns.distplot(concated_df.X_5,kde=True)
print(f'Unique values: {concated_df.X_5.unique()}')
concated_df.X_5.describe().T
# Isnstead of checking distribution of density, I check count distribution.
# Out:
# Unique values: [1 0 5 3 2]
# count    23856.000000
# mean         2.455609
# std          1.963095
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max          5.000000
# Name: X_5, dtype: float64

# %%
sns.countplot(concated_df.X_5,hue=concated_df.MULTIPLE_OFFENSE)
for val in range(concated_df.X_5.max()+1):
  print(f'distribution of value {val}: {np.round(len(concated_df.loc[concated_df.X_5 == val])/len(concated_df.X_5),2)}%')

print(concated_df.groupby(['MULTIPLE_OFFENSE']).X_5.value_counts(normalize=False).unstack())
concated_df.groupby(['MULTIPLE_OFFENSE']).X_5.value_counts(normalize=False).unstack().plot(stacked=False,kind='bar')
print('---------')
print(f'distribution of value according MULTIPLE Offence 1: {np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 1])/len(concated_df.X_5),2)}%')
print(f'distribution of value according MULTIPLE Offence 0: {np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 0])/len(concated_df.X_5),2)}%')
# As we can see, 96% of the data distributted as Multiple_Offence true.
# And 4% of the data distributted as Multiple_Offence false

# I assume, this column contains categorical count values, but here we are missing value 4. We need to check whether missing value is itentional.
# Out:
# distribution of value 0: 0.2%
# distribution of value 1: 0.29%
# distribution of value 2: 0.0%
# distribution of value 3: 0.21%
# distribution of value 4: 0.0%
# distribution of value 5: 0.31%
# X_5                    0       1    2       3       5
# MULTIPLE_OFFENSE
# 0                  196.0   317.0  NaN   218.0   337.0
# 1                 4499.0  6501.0  2.0  4755.0  7031.0
# ---------
# distribution of value according MULTIPLE Offence 1: 0.96%
# distribution of value according MULTIPLE Offence 0: 0.04%

# %%
sns.countplot(test_data_df.X_5)
# As we can see value 4 is missing in Test data also.

# %%
# Let's check distribution of X_6
sns.distplot(concated_df.X_6,kde=True)
concated_df.X_6.describe().T
print(f'Skewness : {concated_df.X_6.skew()}')
# The distribution is moderately skew. We check for outlier.
# Out:
# Skewness : 0.9608294397479427

# %%
print(f'distribution of value according MULTIPLE Offence 1: {np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 1])/len(concated_df.X_6),2)}%')
print(f'distribution of value according MULTIPLE Offence 0: {np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 0])/len(concated_df.X_6),2)}%')
# As we can see, 96% of the data distributted as Multiple_Offence true.
# And 4% of the data distributted as Multiple_Offence false
# Out:
# distribution of value according MULTIPLE Offence 1: 0.96%
# distribution of value according MULTIPLE Offence 0: 0.04%

# %%
# Let's check distribution of X_7
sns.distplot(concated_df.X_7,kde=True,bins=10)
print(f'Skewness of X_7:',concated_df.X_7.skew())
# There is a positve skew. We check for outlier or expected distribution
print(f'distribution of value according MULTIPLE Offence 1: {np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 1])/len(concated_df.X_7),2)}%')
print(f'distribution of value according MULTIPLE Offence 0: {np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 0])/len(concated_df.X_7),2)}%')
# As we can see, 96% of the data distributted as Multiple_Offence true.
# And 4% of the data distributted as Multiple_Offence false
# Out:
# Skewness of X_7: 0.7961675929226415
# distribution of value according MULTIPLE Offence 1: 0.96%
# distribution of value according MULTIPLE Offence 0: 0.04%

# %%
# Let's check distribution of X_8
sns.distplot(concated_df.X_8,kde=True,bins=10)
print(f'Skewness of X_8:',concated_df.X_8.skew())
# The distribution is highly positve-skew. We check for outlier, there might be outliers.
# Out:
# Skewness of X_8: 17.70384903104472

# %%
sns.countplot(concated_df.X_9,hue=concated_df.MULTIPLE_OFFENSE)
for val in range(concated_df.X_9.max()+1):
  print(f'distribution of value {val}: {np.round(len(concated_df.loc[concated_df.X_9 == val])/len(concated_df.X_9),2)}%')
print('---------')
print(f'distribution of value according MULTIPLE Offence 1: {np.round(len(concated_df.X_9.loc[concated_df.MULTIPLE_OFFENSE == 1])/len(concated_df.X_9),2)}%')
print(f'distribution of value according MULTIPLE Offence 0: {np.round(len(concated_df.X_9.loc[concated_df.MULTIPLE_OFFENSE == 0])/len(concated_df.X_9),2)}%')
# As we can see, 96% of the data distributted as Multiple_Offence true.
# And 4% of the data distributted as Multiple_Offence false 
# Most of the data distributted between

print(concated_df.groupby(['MULTIPLE_OFFENSE']).X_9.value_counts(normalize=False).unstack())
concated_df.groupby(['MULTIPLE_OFFENSE']).X_9.value_counts(normalize=False).unstack().plot(stacked=False,kind='bar')
# Out:
# distribution of value 0: 0.0%
# distribution of value 1: 0.01%
# distribution of value 2: 0.13%
# distribution of value 3: 0.02%
# distribution of value 4: 0.0%
# distribution of value 5: 0.44%
# distribution of value 6: 0.4%
# ---------
# distribution of value according MULTIPLE Offence 1: 0.96%
# distribution of value according MULTIPLE Offence 0: 0.04%
# X_9                   0      1       2      3    4        5       6
# MULTIPLE_OFFENSE
# 0                   3.0    5.0   132.0   36.0  NaN    465.0   427.0
# 1                 115.0  170.0  2908.0  416.0  4.0  10094.0  9081.0

# %%
sns.distplot(concated_df.X_10,kde=True,bins=10)
print(f'Skewness of X_10:',concated_df.X_10.skew())
# The distribution is highly positve-skew. We check for outlier, there might be outliers.
# Out:
# Skewness of X_10: 34.94271319604181

# %%
sns.distplot(concated_df.X_11,kde=True,bins=30)
print(f'Skewness of X_11 :{concated_df.X_11.skew()}')
print(f'Description {concated_df.X_11.describe().T}')
# X_11 data distribution is moderately skewed, We check for Outliers in the data.
# Out:
# Skewness of X_11 :-0.9032002687579812
# Description count    23856.000000
# mean       206.954519
# std         93.033348
# min          0.000000
# 25%        174.000000
# 50%        249.000000
# 75%        249.000000
# max        332.000000
# Name: X_11, dtype: float64

# %%
sns.distplot(concated_df.X_12,kde=True,bins=30)
print(f'Skewness of X_12 :{concated_df.X_12.skew()}')
print(f'Description {concated_df.X_12.describe().T}')
print(f'Missing Values Before replacement {concated_df.X_12.isna().sum()}')
# X_12 data is positive skew, We check for Outliers in the data.
# The data ditribution is highly postive-skewed and we have got missing values. So we use median to replace missing values. By replacing value with median, we are introducing bias in orinal data.
concated_df.X_12[concated_df.X_12 > 10].value_counts()
concated_df.X_12.fillna(concated_df.X_12.median(),inplace=True)
print(f'Missing Values after replacement {concated_df.X_12.isna().sum()}')
# Out:
# Skewness of X_12 :30.619083189612176
# Description count    23674.000000
# mean         0.974064
# std          1.167725
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         90.000000
# Name: X_12, dtype: float64
# Missing Values Before replacement 182
# Missing Values after replacement 0

# %%
sns.distplot(concated_df.X_13,kde=True,bins=30)
print(f'Skewness of X_13 :{concated_df.X_13.skew()}')
print(f'Description {concated_df.X_13.describe().T}')
# X_13 distribution is high negative-skew, We check for Outliers in the data.
# Out:
# Skewness of X_13 :-1.3886367487864426
# Description count    23856.000000
# mean        85.237383
# std         27.597226
# min          0.000000
# 25%         72.000000
# 50%         98.000000
# 75%        103.000000
# max        116.000000
# Name: X_13, dtype: float64

# %%
sns.distplot(concated_df.X_14,kde=True,bins=30)
print(f'Skewness of X_14 :{concated_df.X_14.skew()}')
print(f'Description {concated_df.X_14.describe().T}')
# The distribution is  approximately symmetric.
# Out:
# Skewness of X_14 :0.24558776634318077
# Description count    23856.000000
# mean        72.674296
# std         43.297320
# min          0.000000
# 25%         29.000000
# 50%         62.000000
# 75%        107.000000
# max        142.000000
# Name: X_14, dtype: float64

# %%
sns.distplot(concated_df.X_15,kde=True,bins=30)
print(f'Skewness of X_15 :{concated_df.X_15.skew()}')
print(f'Description {concated_df.X_15.describe().T}')
# The distribution is  highly skewed.
# Out:
# Skewness of X_15 :-2.5274537891556634
# Description count    23856.000000
# mean        33.464747
# std          8.386834
# min          0.000000
# 25%         34.000000
# 50%         34.000000
# 75%         34.000000
# max         50.000000
# Name: X_15, dtype: float64

# %%
concated_df.groupby('MULTIPLE_OFFENSE').hist(figsize=(20,10))
# Most of the data is distributted as 1
# Out:
# MULTIPLE_OFFENSE
# 0    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# 1    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# dtype: object

# %%
print(f'{np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 1])/len(concated_df.index)*100,2)}%')
print(f'{np.round(len(concated_df.loc[concated_df.MULTIPLE_OFFENSE == 0])/len(concated_df.index)*100,2)}%')
# Out:
# 95.52%
# 4.48%

# %%
sns.pairplot(concated_df,hue='MULTIPLE_OFFENSE',diag_kind='kde')

# %%
# Let's check corelation of data
corr = concated_df.corr().abs()
plt.figure(figsize=(20,14))
sns.heatmap(corr,cmap='Blues',annot=True)

# %%
# By seeing pair plot and correlation heatmap, we can say a good relation between some features.
# X_1 , X_ 4 and X_5 has good correlation of 0.4
# X_6 and X_7 has good correlation of 0.7
# X_12 and X_10 has good correlation of 0.88
# X_3_ and X_2 has good correlation of 1.0, We can use any one of these.
# I say X_10,X_11,X_12 and X_15 are strong features fro dtecting 'Multiple_offense.

# %%
# Let's check for outliers in data
concated_df.boxplot(figsize=(20,14))

# %%
# As we can see most of the data have outliers.
# But, outliers are close to MAX or MIN vlaue of IQR
# I got with IQR for checking outliers. And use capping method.

# %%
test_df = concated_df.copy(True)
test_df.drop(columns=['MULTIPLE_OFFENSE'],axis=1,inplace=True)
percent_95 = test_df.quantile(0.95)
percent_5 = test_df.quantile(0.05)
IQR = percent_95 - percent_5
print(IQR)
final_concated_df = concated_df[~((test_df < (percent_5 - 1.5 * IQR)) |(test_df > (percent_95 + 1.5 * IQR))).any(axis=1)]
print(concated_df.shape,test_df.shape)
print(final_concated_df.shape[0]/test_df.shape[0] *100)
# Out:
# X_1       3.0
# X_2      45.0
# X_3      45.0
# X_4      10.0
# X_5       5.0
# X_6      14.0
# X_7      12.0
# X_8       3.0
# X_9       4.0
# X_10      1.0
# X_11    316.0
# X_12      2.0
# X_13     94.0
# X_14    113.0
# X_15     23.0
# dtype: float64
# (23856, 16) (23856, 15)
# 97.82863849765259

# %%
final_concated_df.boxplot(figsize=(20,14))

# %%
# We can go ahead with above outliers. As I said, outliers are close to Q1 or Q4 value

# %%
# Check the distribution of the Target column.
sns.distplot(final_concated_df.MULTIPLE_OFFENSE)
print(f'{np.round(len(final_concated_df.loc[final_concated_df.MULTIPLE_OFFENSE == 1])/len(final_concated_df.index)*100,2)}%')
print(f'{np.round(len(final_concated_df.loc[final_concated_df.MULTIPLE_OFFENSE == 0])/len(final_concated_df.index)*100,2)}%')
# Out:
# 96.11%
# 3.89%

# %%
X = final_concated_df.drop(columns=['MULTIPLE_OFFENSE'])
y = final_concated_df['MULTIPLE_OFFENSE']

# %%
# And as we can see, data distribution imbalanced. So I go with 'over sampling' technique SMOTE.
from imblearn.over_sampling import SMOTE

def smoteData(X,y):
  sm = SMOTE(sampling_strategy='all',random_state=42)
  X_res, y_res = sm.fit_resample(X,y)
  return (X_res,y_res)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X_res,y_res = smoteData(X,y)
print(np.bincount(y_res))
sns.distplot(y_res)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [22430 22430]

# %%
X_df = pd.DataFrame(X_res,columns=X.columns)
X_df['MULTIPLE_OFFENSE'] = y_res
X_df.head()
# Out:
#    X_1   X_2   X_3  X_4  X_5  ...  X_12   X_13   X_14  X_15  MULTIPLE_OFFENSE
# 0  0.0  36.0  34.0  2.0  1.0  ...   1.0   92.0   29.0  36.0                 0
# 1  1.0  37.0  37.0  0.0  0.0  ...   1.0  103.0  142.0  34.0                 1
# 2  0.0   3.0   2.0  3.0  5.0  ...   1.0  110.0   93.0  34.0                 1
# 3  0.0  33.0  32.0  2.0  1.0  ...   1.0   72.0   29.0  34.0                 1
# 4  0.0  33.0  32.0  2.0  1.0  ...   0.0  112.0   29.0  43.0                 1
#
# [5 rows x 16 columns]

# %%
# Scale the data.
from sklearn.preprocessing import MinMaxScaler
def scaleData(_X):
  scale = MinMaxScaler()
  X_res_scaled = scale.fit_transform(_X)
  return X_res_scaled

# %%
#Split the data inot training and testing
from sklearn.model_selection import train_test_split
X_res_scaled = scaleData(X_res)
X_train,X_test,y_train,y_test = train_test_split(X_res_scaled,y_res,test_size=0.33, random_state=42)

# %%
from sklearn.tree import  DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score

# %%
# # Let's check model results
def selectModel(X_train,y_train,X_test,y_test):
  rf_clf = RandomForestClassifier()
  svm_clf = SVC()
  lr_clf = LogisticRegression()
  knn_clf = KNeighborsClassifier()
  xg_clf = XGBClassifier()
  ada_clf = AdaBoostClassifier()

  vote_clf = VotingClassifier(estimators=[('lr', lr_clf), ('rf', rf_clf), ('svc', svm_clf),('knn', knn_clf), ('xg', xg_clf),('ada',ada_clf)],voting='hard')

  trainScores = []
  testScores = []
  classNames = []

  for clf in [rf_clf,svm_clf,lr_clf,knn_clf,xg_clf,ada_clf,vote_clf]:
    clf.fit(X_train,y_train)
    y_pred_test = clf.predict(X_test)
    y_pred_train = clf.predict(X_train)
    testScores.append(accuracy_score(y_test,y_pred_test))
    trainScores.append(accuracy_score(y_train,y_pred_train))
    classNames.append(clf.__class__.__name__)
  return (trainScores,testScores,classNames)

# %%
# without feature selection
train_Score,test_score, className = selectModel(X_train,y_train,X_test,y_test)

# %%
model_without_featurSeleciton_df = pd.DataFrame(data=[className,train_Score,test_score])
model_without_featurSeleciton_df = model_without_featurSeleciton_df.T
model_without_featurSeleciton_df.columns = ['Classifier','Train Score','Test Score']
model_without_featurSeleciton_df.head(10)
# As we can see ,other than logistic regression model, other models are giving almost same result.
# I got with Random forest model. which is performing good comapre to others.
# Out:
#                Classifier Train Score Test Score
# 0  RandomForestClassifier           1   0.996893
# 1                     SVC    0.964433   0.963051
# 2      LogisticRegression    0.896194   0.893475
# 3    KNeighborsClassifier    0.978939   0.970143
# 4           XGBClassifier    0.997738    0.99669
# 5      AdaBoostClassifier    0.996906   0.995879
# 6        VotingClassifier    0.988289   0.984193

# %%
#Let's use Decision Tree to check important features
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
dt.feature_importances_
# Out:
# array([2.62604812e-04, 1.27212262e-03, 8.61884593e-04, 3.60438869e-04,
#        4.59779813e-03, 1.26268346e-04, 3.60808550e-04, 4.13990560e-04,
#        5.17553248e-05, 6.62172489e-01, 1.18765749e-01, 5.57127054e-02,
#        2.53418183e-04, 6.41086023e-04, 1.54146880e-01])

# %%
zipped = sorted(list(zip(X.columns,dt.feature_importances_)),key = lambda x: x[1],reverse=True)
print(dict(zipped))
# Out:
# {'X_10': 0.6621724894631166, 'X_15': 0.15414688011583105, 'X_11': 0.11876574903230765, 'X_12': 0.05571270538546093, 'X_5': 0.00459779812567488, 'X_2': 0.0012721226169416621, 'X_3': 0.0008618845925221324, 'X_14': 0.0006410860229018855, 'X_8': 0.0004139905604998159, 'X_7': 0.00036080855000681413, 'X_4': 0.00036043886911541373, 'X_1': 0.0002626048119246285, 'X_13': 0.0002534181831850854, 'X_6': 0.00012626834571537193, 'X_9': 5.17553247960594e-05}

# %%
# Let's check modelss performance with feature selection.
X_selected_feature = X_df[['X_15','X_10','X_12','X_11']]
X_selected_feature_scaled = scaleData(X_selected_feature)
X_sf_train,X_sf_test,y_sf_train,y_sf_test = train_test_split(X_selected_feature_scaled,y_res,test_size=0.33, random_state=42)
train_Score,test_score, className = selectModel(X_sf_train,y_sf_train,X_sf_test,y_sf_test)

# %%
model_with_featurSeleciton_df = pd.DataFrame(data=[className,train_Score,test_score])
model_with_featurSeleciton_df = model_with_featurSeleciton_df.T
model_with_featurSeleciton_df.columns = ['Classifier','Train Score','Test Score']
model_with_featurSeleciton_df.head(10)
# Out:
#                Classifier Train Score Test Score
# 0  RandomForestClassifier           1   0.999325
# 1                     SVC    0.963302   0.963726
# 2      LogisticRegression    0.885114   0.881991
# 3    KNeighborsClassifier    0.998503   0.998311
# 4           XGBClassifier    0.997738    0.99723
# 5      AdaBoostClassifier    0.996806   0.995879
# 6        VotingClassifier    0.997238   0.996285

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10 , stop = 15, num = 2)]   # returns evenly spaced 10 numbers
# Number of features to consider at every split
max_features = ['auto', 'log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 10, num = 2)]  # returns evenly spaced numbers can be changed to any
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

print(random_grid)

rf_random = RandomizedSearchCV(estimator=RandomForestClassifier(), param_distributions=random_grid,n_iter = 5, cv = 3,
                               verbose=2,
                               random_state=42,
                               n_jobs=-1,
                               return_train_score=True)
rf_random.fit(X_sf_train,y_sf_train)
# Out:
# {'n_estimators': [10, 15], 'max_features': ['auto', 'log2'], 'max_depth': [5, 10, None], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    3.3s finished
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
# ...

# %%
best_n_estimators = rf_random.best_estimator_.get_params()['n_estimators']
best_max_features = rf_random.best_estimator_.get_params()['max_features']
best_max_depth = rf_random.best_estimator_.get_params()['max_depth']
best_min_samples_split = rf_random.best_estimator_.get_params()['min_samples_split']
best_min_samples_leaf = rf_random.best_estimator_.get_params()['min_samples_leaf']
best_bootstrap = rf_random.best_estimator_.get_params()['bootstrap']

# %%
# Let's build Random formest model
random_forest_best_model = RandomForestClassifier(n_estimators=best_n_estimators,
                                                 max_features=best_max_features,
                                                 max_depth=best_max_depth,
                                                 min_samples_split=best_min_samples_split,
                                                 min_samples_leaf=best_min_samples_leaf,
                                                 bootstrap=best_bootstrap)
random_forest_best_model.fit(X_sf_train,y_sf_train)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=15,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
test_pred = random_forest_best_model.predict(X_sf_test)
accuracy_score(y_sf_test,test_pred)
# Out:
# 0.9991894082680357

# %%
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import confusion_matrix,classification_report

# %%
ns_probs = [0 for _ in range(len(y_test))]

def drawROC_Curve(y_true,y_pred,model_name):
    plt.figure(figsize=(10,5))
    roc_score = roc_auc_score(y_true,y_pred)
    ns_fpr,ns_tpr, ns_threshold = roc_curve(y_true,ns_probs)
    fpr,tpr, threshold = roc_curve(y_true,y_pred)
    plt.plot(ns_fpr,ns_tpr,linestyle='--', label="No skill")
    plt.plot(fpr,tpr,linestyle='solid',label=f'Model name: {model_name} and roc_Score is: {np.round(roc_score,4)}')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.legend()

def printConfusionMatrix(y_true,y_pred):
    cm = confusion_matrix(y_true,y_pred)
    report = classification_report(y_true,y_pred)
    print(f'Confusion Matrix:\n{cm} \n')
    print(f'Classidfication Report: {report}')
    cm_df = pd.DataFrame(cm,index=[i for i in '01'], columns= [i for i in '01'])
    sns.heatmap(cm_df,annot=True)
    return cm

# %%
drawROC_Curve(y_sf_test,test_pred,'RondomForestClf')

# %%
rf_cm = printConfusionMatrix(y_sf_test,test_pred)
# Out:
# Confusion Matrix:
# [[7375    8]
#  [   4 7417]]
#
# Classidfication Report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7383
#            1       1.00      1.00      1.00      7421
#
#     accuracy                           1.00     14804
#    macro avg       1.00      1.00      1.00     14804
# weighted avg       1.00      1.00      1.00     14804

# %%
test_data_df.isna().sum()
# Out:
# INCIDENT_ID      0
# DATE             0
# X_1              0
# X_2              0
# X_3              0
# X_4              0
# X_5              0
# X_6              0
# X_7              0
# X_8              0
# X_9              0
# X_10             0
# X_11             0
# X_12           127
# X_13             0
# X_14             0
# X_15             0
# dtype: int64

# %%
sns.distplot(test_data_df.X_12)

# %%
final_test_data =  test_data_df.drop(columns=['INCIDENT_ID','DATE']).copy(True)
# print(final_test_data.X_12.median)
temp_df = final_test_data.fillna(final_test_data.median())
temp_df.head()
# Out:
#    X_1  X_2  X_3  X_4  X_5  X_6  X_7  ...  X_9  X_10  X_11  X_12  X_13  X_14  X_15
# 0    0   30   35    7    3    6    4  ...    5     1   174   1.0    72   119    23
# 1    0   44   44    1    3    7    1  ...    6     1   316   0.0    12    29    34
# 2    0   34   33    3    5    2    7  ...    0     1   316   1.0    72     0    34
# 3    7    3    2    3    5    9    8  ...    5     1   174   1.0   112    87    34
# 4    0    7    8    7    3    2    7  ...    5     1   174   0.0   112    93    43
#
# [5 rows x 15 columns]

# %%
final_test_data_df = temp_df[['X_15','X_11','X_12','X_10']]
final_test_data_df
# Out:
#        X_15  X_11  X_12  X_10
# 0        23   174   1.0     1
# 1        34   316   0.0     1
# 2        34   316   1.0     1
# 3        34   174   1.0     1
# 4        43   174   0.0     1
# ...     ...   ...   ...   ...
# 15898    43   174   0.0     1
# 15899    34     0   2.0     2
# 15900    34     0   1.0     1
# 15901    34   249   2.0     2
# 15902    34   249   1.0     1
#
# [15903 rows x 4 columns]

# %%
X_scaled_test = scaleData(final_test_data_df)
# print(np.isnan(X_scaled_test))
final_pred = random_forest_best_model.predict(X_scaled_test)
# Out:
# [[False False False False]
#  [False False False False]
#  [False False False False]
#  ...
#  [False False False False]
#  [False False False False]
#  [False False False False]]

# %%
print(len(final_pred[final_pred==1]))
print(len(final_pred[final_pred==0]))
# Out:
# 13744
# 2159

# %%
IDs = np.reshape(test_data_df.INCIDENT_ID.values,(len(test_data_df.INCIDENT_ID.values),1))
# Out:
# (15903, 1)

# %%
final_pred = final_pred.reshape(len(final_pred),1)
IDs.shape,final_pred.shape
# Out:
# ((15903, 1), (15903, 1))

# %%
test_data_df['MULTIPLE_OFFENSE'] = final_pred
final_result = test_data_df[['INCIDENT_ID','MULTIPLE_OFFENSE']]
final_result.head()
# Out:
#   INCIDENT_ID  MULTIPLE_OFFENSE
# 0   CR_195453                 1
# 1   CR_103520                 1
# 2   CR_196089                 1
# 3   CR_112195                 1
# 4   CR_149832                 1

# %%
#Final result.
final_result.to_csv('submission.csv',index=False)
